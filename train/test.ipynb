# %%
from LevelTwoEnv import LevelTwoEnv 
import gymnasium as gym
from gymnasium import spaces

import pygame
import random
import numpy as np

from Agent import Agent
from gymnasium.envs.registration import register
from typing import Optional, Union
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from LevelTwoEnv import LevelTwoEnv
#       2 import gymnasium as gym
#       3 from gymnasium import spaces
#
# File c:\Users\boredbedouin\Desktop\PlaygroundRL\train\LevelTwoEnv.py:1
# ----> 1 import gymnasium as gym
#       2 from gymnasium import spaces
#       4 import pygame
#
# ModuleNotFoundError: No module named 'gymnasium'

# %%
random.seed(1)
np.random.seed(1)
torch.manual_seed(1)

# %%
env = gym.make('LevelTwo')

# %%
env.reset(seed=1)
# Out:
# (array([1.        , 0.        , 0.        , 1.        , 0.        ,
#         0.        , 1.        , 0.        , 0.        , 0.56      ,
#         0.        , 0.36      , 0.32      , 0.37735925]),
#  {})

# %%
env.hologram_tiles
# Out:
# [[16, 18], [8, 12], [8, 22], [8, 15], [10, 1], [14, 18], [21, 4], [6, 21]]

# %%
obs, reward, terminated, truncated, info = env.step(3)

print(f'obs: {obs}')
print(f'reward: {reward}')
print(f'done {terminated or truncated}')
print(f'info: {info}')
# Out:
# [21, 4]
# [[16, 18], [8, 12], [8, 22], [8, 15], [10, 1], [14, 18], [21, 4], [6, 21]]
# obs: [ 0.          0.          0.          0.          1.          0.
#   0.          0.          0.         21.          4.         17.
#   8.          5.65685425]
# reward: -9
# done True
# info: {}
